# %% [markdown]
# ```mermaid
#
# graph TD
#     A[app.py] -->|imports| B[data_loader.py]
#     A -->|imports| C[layout.py]
#     A -->|imports| D[callbacks.py]
#     A -->|imports| E[config.py]
#
#     D -->|uses functions from| F[graph_utils.py]
#     D -->|calls| G[query_handler.py]
#
#     F -->|relies on| H[networkx / plotly / pyvis]
#     G -->|relies on| E
#
#     subgraph "Utilities & Core Logic"
#     F
#     G
#     end
#
#     subgraph "App Framework"
#     B
#     C
#     D
#     end
#
#     subgraph "Configuration Layer"
#     E
#     end
#
#     style A fill:#3498db,stroke:#2c3e50,color:#fff
#     style E fill:#f1c40f,stroke:#b7950b
#     style F fill:#27ae60,stroke:#1e8449,color:#fff
#     style G fill:#27ae60,stroke:#1e8449,color:#fff
#     style B fill:#9b59b6,stroke:#6c3483,color:#fff
#     style C fill:#9b59b6,stroke:#6c3483,color:#fff
#     style D fill:#9b59b6,stroke:#6c3483,color:#fff
#     '''
